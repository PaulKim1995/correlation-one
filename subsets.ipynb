# %%
# Question: What do characteristics of airbnb customers percieve to be "good value"? 
# How can airbnb renters improve the reviews that they get? What kind of things are important to an airbnb locations score?
# We should subset the above by either the number of people each place accommodates, or the nubmer of bedrooms, to ge tmore
# granular tips
# We should have 3 sections, so each renter can look at what section they are in and look at whats important for those
# types of properties. 

# We should subset based on price bins, number of bedrooms, and city. 

ls

# %%
data = pd.get_dummies(data, columns=['cancellation_policy', 'instant_bookable'])

# %%
data.head()
# Out:
#    accommodates                                          amenities  bedrooms  \
# 1           2.0                                                 {}       1.0
# 2           2.0  {"Wireless Internet","Air conditioning","Wheel...       1.0
# 3           6.0  {TV,"Wireless Internet","Air conditioning",Poo...       1.0
# 4           1.0  {Internet,"Wireless Internet",Kitchen,"Free pa...       1.0
# 6           2.0  {Internet,"Wireless Internet","Free parking on...       1.0
#
#      price  review_scores_checkin  review_scores_cleanliness  \
# 1   $50.00                   10.0                       10.0
# 2   $55.00                   10.0                       10.0
# 3  $150.00                   10.0                       10.0
# 4   $30.00                   10.0                        9.0
# 6   $45.00                   10.0                       10.0
#
#    review_scores_communication  review_scores_location  review_scores_rating  \
# ...

# %%
data.columns[0]
# Out:
# 'accommodates'

# %%
data.groupby('bedrooms')

# %%
def f(name, group):
    results = smf.ols('review_scores_rating ~ review_scores_cleanliness + review_scores_communication + review_scores_location + review_scores_checkin + cancellation_policy_flexib', data=group).fit()
    print(name)
    print(results.summary())

# %%
for name, group in data.groupby('metropolitan'):
    results = smf.ols('review_scores_rating ~ review_scores_cleanliness + review_scores_communication + review_scores_location + review_scores_checkin + cancellation_policy_flexible + instant_bookable_t', data=group).fit()
    
    print('metropolitan', name)
    print(results.summary())
# Out:
# metropolitan LA
#                              OLS Regression Results
# ...
# Dep. Variable:     review_scores_rating   R-squared:                       0.685
# Model:                              OLS   Adj. R-squared:                  0.685
# Method:                   Least Squares   F-statistic:                     8562.
# Date:                  Sat, 09 Sep 2017   Prob (F-statistic):               0.00
# Time:                          10:52:21   Log-Likelihood:                -68477.
# No. Observations:                 23587   AIC:                         1.370e+05
# Df Residuals:                     23580   BIC:                         1.370e+05
# Df Model:                             6
# Covariance Type:              nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
