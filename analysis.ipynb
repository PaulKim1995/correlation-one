# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import tools
import matplotlib.pyplot as plt
# Out:
# /Users/Paul/anaconda/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data, amentities = tools.load_listings()
data['self_check_in'] = data['self_check-in']
data['family_friendly'] = data['family/kid_friendly']
data = data.dropna()
# Out:
# /Users/Paul/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# WARNING:root:You have expanded a column of 92 tags

# %%
model_params = 'review_scores_rating ~ review_scores_cleanliness + review_scores_communication + review_scores_location + review_scores_checkin + wireless_internet + air_conditioning + kitchen + heating + pets_allowed + cable_tv + family_friendly + cancellation_policy_flexible + instant_bookable'

# %% [markdown]
# # Subsetting based on metro area

# %%
for name, group in data.groupby('metropolitan'):
    results = smf.ols(model_params, data=group).fit()
    
    print('metro_area', name)
    print(results.summary())
# Out:
# metro_area LA
#                              OLS Regression Results
# ...
# Dep. Variable:     review_scores_rating   R-squared:                       0.669
# Model:                              OLS   Adj. R-squared:                  0.668
# Method:                   Least Squares   F-statistic:                     1006.
# Date:                  Sat, 09 Sep 2017   Prob (F-statistic):               0.00
# Time:                          13:04:51   Log-Likelihood:                -17927.
# No. Observations:                  6492   AIC:                         3.588e+04
# Df Residuals:                      6478   BIC:                         3.598e+04
# Df Model:                            13
# Covariance Type:              nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Subsetting based on number of bedrooms

# %%
for name, group in data.groupby('bedrooms'):
    results = smf.ols(model_params, data=group).fit()
    
    print('number of bedrooms:', name)
    print(results.summary())
    if name == 4:
        break
# Out:
# number of bedrooms: 0.0
#                              OLS Regression Results
# ...
# Dep. Variable:     review_scores_rating   R-squared:                       0.628
# Model:                              OLS   Adj. R-squared:                  0.625
# Method:                   Least Squares   F-statistic:                     163.0
# Date:                  Sat, 09 Sep 2017   Prob (F-statistic):          3.10e-258
# Time:                          13:06:59   Log-Likelihood:                -3396.0
# No. Observations:                  1267   AIC:                             6820.
# Df Residuals:                      1253   BIC:                             6892.
# Df Model:                            13
# Covariance Type:              nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Subsetting based on number of room type

# %%
for name, group in data.groupby('room_type'):
    results = smf.ols(model_params, data=group).fit()
    
    print('room type:', name)
    print(results.summary())
# Out:
# room type: Entire home/apt
#                              OLS Regression Results
# ...
# Dep. Variable:     review_scores_rating   R-squared:                       0.611
# Model:                              OLS   Adj. R-squared:                  0.610
# Method:                   Least Squares   F-statistic:                     1072.
# Date:                  Sat, 09 Sep 2017   Prob (F-statistic):               0.00
# Time:                          13:07:45   Log-Likelihood:                -24710.
# No. Observations:                  8893   AIC:                         4.945e+04
# Df Residuals:                      8879   BIC:                         4.955e+04
# Df Model:                            13
# Covariance Type:              nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Overall

# %%
results = smf.ols(model_params, data=data).fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     review_scores_rating   R-squared:                       0.649
# Model:                              OLS   Adj. R-squared:                  0.649
# Method:                   Least Squares   F-statistic:                     2006.
# Date:                  Sat, 09 Sep 2017   Prob (F-statistic):               0.00
# Time:                          13:13:08   Log-Likelihood:                -39080.
# No. Observations:                 14131   AIC:                         7.819e+04
# Df Residuals:                     14117   BIC:                         7.829e+04
# Df Model:                            13
# Covariance Type:              nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
for name, group in data.groupby('accommodates'):
    results = smf.ols(model_params, data=group).fit()
    
    print('Accommodates', name)
    print(results.summary())
# Out:
# Accommodates 1.0
#                              OLS Regression Results
# ...
# Dep. Variable:     review_scores_rating   R-squared:                       0.531
# Model:                              OLS   Adj. R-squared:                  0.525
# Method:                   Least Squares   F-statistic:                     95.26
# Date:                  Sat, 09 Sep 2017   Prob (F-statistic):          1.64e-169
# Time:                          15:12:10   Log-Likelihood:                -3364.9
# No. Observations:                  1109   AIC:                             6758.
# Df Residuals:                      1095   BIC:                             6828.
# Df Model:                            13
# Covariance Type:              nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...
